# %%
import pandas as pd

# %%
df = pd.read_excel("data/us_census/state_surface_area.xlsx")

# %%
from get_population_by_state import GetAgeSex

# %%
df = GetAgeSex('2017').read_file_by_population()

# %%
df
# Out:
#     STATE                  NAME  SEX  POPEST2017_CIV State and other areas2  \
# 0       0         United States    0       323794924          United States
# 1       1               Alabama    0         4861465                Alabama
# 2       2                Alaska    0          718487                 Alaska
# 3       4               Arizona    0         7025816                Arizona
# 4       5              Arkansas    0         2995637               Arkansas
# 5       6            California    0        39197779             California
# 6       8              Colorado    0         5575734               Colorado
# 7       9           Connecticut    0         3565967            Connecticut
# 8      10              Delaware    0          953449               Delaware
# 9      11  District of Columbia    0          690589   District of Columbia
# 10     12               Florida    0        20895127                Florida
# ...
