# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
from scipy import stats

# %%
ev_df = pd.read_csv("data/ev_sales/ev_data_preprocessed.csv")
asthma_df = pd.read_csv("output_files/combined_AF_pm2.5.csv")
df = ev_df.merge(asthma_df, how='left', on=['state_code', 'year'])
df = df[df['year']>=2013]

# %%
df
# Out:
#              State  FCEV Sales  FCEV Market Share  BEV Sales  \
# 102        Alabama           0                0.0         77
# 103         Alaska           0                0.0         17
# 104        Arizona           0                0.0        705
# 105       Arkansas           0                0.0         24
# 106     California          19                0.0      20943
# ..             ...         ...                ...        ...
# 454       Virginia           0                0.0       5677
# 455     Washington           0                0.0      10256
# 456  West Virginia           0                0.0        179
# 457      Wisconsin           0                0.0       1381
# 458        Wyoming           0                0.0        100
#
#      BEV Market Share  PHEV Sales  PHEV Market Share  year     State Name  \
# 102            0.0004          99             0.0005  2013        Alabama
# 103            0.0007          26             0.0010  2013         Alaska
# 104            0.0023         544             0.0017  2013        Arizona
# 105            0.0002          74             0.0006  2013       Arkansas
# 106            0.0129       17512             0.0108  2013     California
# ..                ...         ...                ...   ...            ...
# 454            0.0153        1337             0.0036  2019       Virginia
# 455            0.0359        1916             0.0067  2019     Washington
# 456            0.0035          71             0.0014  2019  West Virginia
# 457            0.0057         581             0.0024  2019      Wisconsin
# 458            0.0028          44             0.0012  2019        Wyoming
#
#      state_code  ...      total  nonev_sales  ZEV Mandates  population  \
# 102           1  ...   198000.0     197824.0           0.0   1109908.0
# 103           2  ...    26000.0      25957.0           0.0    188349.0
# 104           4  ...   320000.0     318751.0           0.0   1618036.0
# 105           5  ...   123334.0     123236.0           0.0    708960.0
# 106           6  ...  1623489.0    1585015.0           1.0   9157430.0
# ..          ...  ...        ...          ...           ...         ...
# 454          51  ...   371389.0     364375.0           0.0   1860848.0
# 455          53  ...   285971.0     273799.0           0.0   1663061.0
# 456          54  ...    51143.0      50893.0           0.0    359567.0
# 457          55  ...   242281.0     240319.0           0.0   1266597.0
# 458          56  ...    36667.0      36523.0           0.0    133734.0
#
#        at_risk  total_incidence  incidence_trap        PR        IR        AF
# 102  1008261.0           8089.0          2336.0  0.091582  0.008022  0.288787
# 103   171100.0           1373.0           319.0  0.091582  0.008022  0.232081
# 104  1443148.0          11578.0          3465.0  0.108087  0.008022  0.299213
# 105   644033.0           5167.0          1422.0  0.091582  0.008022  0.275082
# 106  8346688.0          42984.0         17875.0  0.088534  0.005150  0.415853
# ..         ...              ...             ...       ...       ...       ...
# 454  1724639.0          10676.0          1549.0  0.073197  0.006190  0.145019
# 455  1541330.0           9541.0          2435.0  0.073197  0.006190  0.255149
# 456   333248.0           2063.0           296.0  0.073197  0.006190  0.143035
# 457  1214574.0           7519.0          1374.0  0.041074  0.006190  0.182722
# 458   123946.0            768.0            94.0  0.073197  0.006190  0.122318
#
# [357 rows x 23 columns]

# %%
df['pre_trap'] = df['population']*df['PR']*df['AF']
df['ev_market_share'] = df['ev_sales']/df['total']
df['nonev_market_share'] = df['nonev_sales']/df['total']
# df = df[df['OR'] != 9999]

df['ev_sales_log'] = np.log(df['ev_sales'])
df['nonev_sales_log'] = np.log(df['nonev_sales'])

# %%
def calco(df):
    return df[['ev_sales', 'nonev_sales', 'AF', 'incidence_trap', 'pre_trap', 'ev_market_share', 'nonev_market_share', 
               'ev_sales_log', 'nonev_sales_log']].corr()

# %%
calco(df)
# Out:
#                     ev_sales  nonev_sales        AF  incidence_trap  pre_trap  \
# ev_sales            1.000000     0.608663  0.277869        0.730143  0.680521
# nonev_sales         0.608663     1.000000  0.283436        0.851172  0.871795
# AF                  0.277869     0.283436  1.000000        0.466433  0.479296
# incidence_trap      0.730143     0.851172  0.466433        1.000000  0.930567
# pre_trap            0.680521     0.871795  0.479296        0.930567  1.000000
# ev_market_share     0.708077     0.300510  0.176440        0.387396  0.364069
# nonev_market_share -0.708077    -0.300510 -0.176440       -0.387396 -0.364069
# ev_sales_log        0.506845     0.682963  0.224507        0.598110  0.611181
# nonev_sales_log     0.376865     0.842581  0.248455        0.671151  0.698423
#
#                     ev_market_share  nonev_market_share  ev_sales_log  \
# ev_sales                   0.708077           -0.708077      0.506845
# nonev_sales                0.300510           -0.300510      0.682963
# AF                         0.176440           -0.176440      0.224507
# incidence_trap             0.387396           -0.387396      0.598110
# pre_trap                   0.364069           -0.364069      0.611181
# ev_market_share            1.000000           -1.000000      0.635143
# nonev_market_share        -1.000000            1.000000     -0.635143
# ev_sales_log               0.635143           -0.635143      1.000000
# nonev_sales_log            0.172106           -0.172106      0.769615
#
#                     nonev_sales_log
# ev_sales                   0.376865
# nonev_sales                0.842581
# AF                         0.248455
# incidence_trap             0.671151
# pre_trap                   0.698423
# ev_market_share            0.172106
# nonev_market_share        -0.172106
# ev_sales_log               0.769615
# nonev_sales_log            1.000000

# %%
tdf = df[df['ZEV Mandates'] == 1]
calco(tdf)
# Out:
#                     ev_sales  nonev_sales        AF  incidence_trap  pre_trap  \
# ev_sales            1.000000     0.806656  0.526648        0.808577  0.778609
# nonev_sales         0.806656     1.000000  0.605908        0.923948  0.932026
# AF                  0.526648     0.605908  1.000000        0.686388  0.694260
# incidence_trap      0.808577     0.923948  0.686388        1.000000  0.938558
# pre_trap            0.778609     0.932026  0.694260        0.938558  1.000000
# ev_market_share     0.867855     0.591081  0.244486        0.597944  0.573975
# nonev_market_share -0.867855    -0.591081 -0.244486       -0.597944 -0.573975
# ev_sales_log        0.729114     0.857623  0.443522        0.758307  0.764455
# nonev_sales_log     0.569814     0.871265  0.588427        0.735789  0.748215
#
#                     ev_market_share  nonev_market_share  ev_sales_log  \
# ev_sales                   0.867855           -0.867855      0.729114
# nonev_sales                0.591081           -0.591081      0.857623
# AF                         0.244486           -0.244486      0.443522
# incidence_trap             0.597944           -0.597944      0.758307
# pre_trap                   0.573975           -0.573975      0.764455
# ev_market_share            1.000000           -1.000000      0.732461
# nonev_market_share        -1.000000            1.000000     -0.732461
# ev_sales_log               0.732461           -0.732461      1.000000
# nonev_sales_log            0.397618           -0.397618      0.881123
#
#                     nonev_sales_log
# ev_sales                   0.569814
# nonev_sales                0.871265
# AF                         0.588427
# incidence_trap             0.735789
# pre_trap                   0.748215
# ev_market_share            0.397618
# nonev_market_share        -0.397618
# ev_sales_log               0.881123
# nonev_sales_log            1.000000

# %%
tdf = df[df['ZEV Mandates'] == 0]
calco(tdf)
# Out:
#                     ev_sales  nonev_sales        AF  incidence_trap  pre_trap  \
# ev_sales            1.000000     0.587674  0.046682        0.462099  0.465322
# nonev_sales         0.587674     1.000000  0.119546        0.827681  0.839145
# AF                  0.046682     0.119546  1.000000        0.374485  0.384322
# incidence_trap      0.462099     0.827681  0.374485        1.000000  0.909490
# pre_trap            0.465322     0.839145  0.384322        0.909490  1.000000
# ev_market_share     0.574875    -0.032018  0.090542       -0.066419 -0.032714
# nonev_market_share -0.574875     0.032018 -0.090542        0.066419  0.032714
# ev_sales_log        0.771126     0.605451  0.119670        0.547768  0.555163
# nonev_sales_log     0.571805     0.848617  0.129158        0.763591  0.762649
#
#                     ev_market_share  nonev_market_share  ev_sales_log  \
# ev_sales                   0.574875           -0.574875      0.771126
# nonev_sales               -0.032018            0.032018      0.605451
# AF                         0.090542           -0.090542      0.119670
# incidence_trap            -0.066419            0.066419      0.547768
# pre_trap                  -0.032714            0.032714      0.555163
# ev_market_share            1.000000           -1.000000      0.548545
# nonev_market_share        -1.000000            1.000000     -0.548545
# ev_sales_log               0.548545           -0.548545      1.000000
# nonev_sales_log            0.002666           -0.002666      0.749209
#
#                     nonev_sales_log
# ev_sales                   0.571805
# nonev_sales                0.848617
# AF                         0.129158
# incidence_trap             0.763591
# pre_trap                   0.762649
# ev_market_share            0.002666
# nonev_market_share        -0.002666
# ev_sales_log               0.749209
# nonev_sales_log            1.000000

# %%
calco(df[df['state_code'] != 6])
# Out:
#                     ev_sales  nonev_sales        AF  incidence_trap  pre_trap  \
# ev_sales            1.000000     0.596005  0.028619        0.435246  0.443760
# nonev_sales         0.596005     1.000000  0.134857        0.828754  0.849448
# AF                  0.028619     0.134857  1.000000        0.388330  0.394250
# incidence_trap      0.435246     0.828754  0.388330        1.000000  0.911222
# pre_trap            0.443760     0.849448  0.394250        0.911222  1.000000
# ev_market_share     0.561964    -0.045125  0.002217       -0.101758 -0.074117
# nonev_market_share -0.561964     0.045125 -0.002217        0.101758  0.074117
# ev_sales_log        0.777842     0.605329  0.115480        0.532088  0.539892
# nonev_sales_log     0.584842     0.857727  0.170238        0.773120  0.776395
#
#                     ev_market_share  nonev_market_share  ev_sales_log  \
# ev_sales                   0.561964           -0.561964      0.777842
# nonev_sales               -0.045125            0.045125      0.605329
# AF                         0.002217           -0.002217      0.115480
# incidence_trap            -0.101758            0.101758      0.532088
# pre_trap                  -0.074117            0.074117      0.539892
# ev_market_share            1.000000           -1.000000      0.563493
# nonev_market_share        -1.000000            1.000000     -0.563493
# ev_sales_log               0.563493           -0.563493      1.000000
# nonev_sales_log           -0.000206            0.000206      0.743018
#
#                     nonev_sales_log
# ev_sales                   0.584842
# nonev_sales                0.857727
# AF                         0.170238
# incidence_trap             0.773120
# pre_trap                   0.776395
# ev_market_share           -0.000206
# nonev_market_share         0.000206
# ev_sales_log               0.743018
# nonev_sales_log            1.000000

# %%
x, y = df['ev_sales'], df['incidence_trap']

print(np.corrcoef(x,y))
plt.scatter(x, y)
# Out:
# [[1.         0.73014313]
#  [0.73014313 1.        ]]

# %%
# remove outliers

def remove_out(df, cols):
    for col in cols:
        df = df[(np.abs(stats.zscore(df[col])) < 3)]
    return df
        
tdf = remove_out(df, ['ev_sales', 'incidence_trap'])
x, y = tdf['ev_sales'], tdf['incidence_trap']
print(np.corrcoef(x,y))
plt.scatter(x, y)
# Out:
# [[1.         0.44603072]
#  [0.44603072 1.        ]]

# %%
# ev_sales and incidence_trap

min_trap, max_trap = np.percentile(df['incidence_trap'], 10), np.percentile(df['incidence_trap'], 90)
min_ev, max_ev = np.percentile(df['ev_sales'], 10), np.percentile(df['ev_sales'], 90)

filtr = (df['ev_sales'] < max_ev) & (df['ev_sales'] > min_ev) & (df['incidence_trap'] < max_trap) & (df['incidence_trap'] > min_trap)
tdf = df[filtr]
x, y = tdf['ev_sales'], tdf['incidence_trap']
print(np.corrcoef(x,y))
plt.scatter(x, y)
# Out:
# [[1.        0.4052286]
#  [0.4052286 1.       ]]

# %%
# non ev sales

tdf = df[df['year']>=2013]
min_trap, max_trap = np.percentile(tdf['incidence_trap'], 10), np.percentile(tdf['incidence_trap'], 90)
min_ev, max_ev = np.percentile(tdf['nonev_sales'], 10), np.percentile(tdf['nonev_sales'], 90)

filtr = (tdf['nonev_sales'] < max_ev) & (tdf['nonev_sales'] > min_ev) & (tdf['incidence_trap'] < max_trap) & (tdf['incidence_trap'] > min_trap)
tdf = tdf[filtr]
x, y = tdf['nonev_sales'], tdf['incidence_trap']
print(np.corrcoef(x,y))
plt.scatter(x, y)
# Out:
# [[1.         0.80470692]
#  [0.80470692 1.        ]]

# %%
tdf = tdf[tdf['year']>2013]
x, y = tdf['nonev_sales'], tdf['incidence_trap']
print(np.corrcoef(x,y))
# Out:
# [[1.         0.80968442]
#  [0.80968442 1.        ]]

# %%
replace_year = {i:j for i, j in zip(range(2011, 2020), range(1, 12))}
df['year_fixed'] = df['year'].replace(replace_year)

# %%
df = df.rename(columns={'ZEV Mandates': 'ZEV_Mandates', 'EPA Region': 'EPA_Region'})

# %%
df.to_csv("output_files/for_R_pm2.5.csv", index=False)

# %%
tdf = df[df['year']>=2013]
min_trap, max_trap = np.percentile(tdf['incidence_trap'], 10), np.percentile(tdf['incidence_trap'], 90)
min_nonev, max_nonev = np.percentile(tdf['nonev_sales'], 10), np.percentile(tdf['nonev_sales'], 90)
min_ev, max_ev = np.percentile(tdf['ev_sales'], 10), np.percentile(tdf['ev_sales'], 90)


filtr = (tdf['ev_sales'] < max_ev) & (tdf['ev_sales'] > min_ev) & (tdf['nonev_sales'] < max_nonev) & (tdf['nonev_sales'] > min_nonev) & (tdf['incidence_trap'] < max_trap) & (tdf['incidence_trap'] > min_trap)
tdf = tdf[filtr]
tdf.to_csv("output_files/for_R_pm2.5_filter_by_per_v2.csv", index=False)

# %%
def get_IQR(df, col):
    return np.percentile(tdf[col], 75) - np.percentile(tdf[col], 25)

-9.098e-02  * get_IQR(tdf, 'ev_sales'),  9.116e-03* get_IQR(tdf, 'nonev_sales')
# Out:
# (-158.646375, 1528.4364190000001)

# %%
get_IQR(tdf, 'ev_sales')
# Out:
# 1743.75

# %%
-2.136e-02 * get_IQR(tdf, 'ev_sales')
# Out:
# -37.2465
