# %%
import json
import pandas as pd
import numpy as np

# %%
a = [4,5,6,8,9,5,6,5]
b = ['a', 'a', 'b', 'b', 'c', 'd', 'e', 'e']
w = [2,1,2,1,2,1,3,1]

data = list(map(list, zip(*[a, b, w])))

# %%
df = pd.DataFrame(data=data, columns=['a', 'b', 'c'])

# %%
df
# Out:
#    a  b  c
# 0  4  a  2
# 1  5  a  1
# 2  6  b  2
# 3  8  b  1
# 4  9  c  2
# 5  5  d  1
# 6  6  e  3
# 7  5  e  1

# %%
t = []

for index, row in df.iterrows():
    t.append(row.tolist())

# %%
pd.DataFrame(data=t, columns=df.columns)
# Out:
#    a  b  c
# 0  4  a  2
# 1  5  a  1
# 2  6  b  2
# 3  8  b  1
# 4  9  c  2
# 5  5  d  1
# 6  6  e  3
# 7  5  e  1

# %%
df.loc[np.repeat(df.index.values, w)]
# Out:
#    a  b  c
# 0  4  a  2
# 0  4  a  2
# 1  5  a  1
# 2  6  b  2
# 2  6  b  2
# 3  8  b  1
# 4  9  c  2
# 4  9  c  2
# 5  5  d  1
# 6  6  e  3
# 6  6  e  3
# 6  6  e  3
# 7  5  e  1

# %%
t = []
for index, row in df.iterrows():
    weight = int(row['c'])
    row_t = []
    for j in range(weight):
        row_t.append(row)
    t.extend(row_t)
    #t.extend([row] * weight)
new_df = pd.DataFrame(data=t)
new_df
# Out:
#    a  b  c
# 0  4  a  2
# 0  4  a  2
# 1  5  a  1
# 2  6  b  2
# 2  6  b  2
# 3  8  b  1
# 4  9  c  2
# 4  9  c  2
# 5  5  d  1
# 6  6  e  3
# 6  6  e  3
# 6  6  e  3
# 7  5  e  1

# %%
s = """
{"search-results":{"opensearch:totalResults":"68972","opensearch:startIndex":"0","opensearch:itemsPerPage":"25","opensearch:Query":{"@role": "request", "@searchTerms": "smart homes", "@startPage": "0"},"link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/search/sciencedirect?start=0&count=25&query=smart+homes&apiKey=7f59af901d2d86f78a1fd60c1bf9426a&httpAccept=application%2Fjson", "@type": "application/json"},{"@_fa": "true", "@ref": "first", "@href": "https://api.elsevier.com/content/search/sciencedirect?start=0&count=25&query=smart+homes&apiKey=7f59af901d2d86f78a1fd60c1bf9426a&httpAccept=application%2Fjson", "@type": "application/json"},{"@_fa": "true", "@ref": "next", "@href": "https://api.elsevier.com/content/search/sciencedirect?start=25&count=25&query=smart+homes&apiKey=7f59af901d2d86f78a1fd60c1bf9426a&httpAccept=application%2Fjson", "@type": "application/json"},{"@_fa": "true", "@ref": "last", "@href": "https://api.elsevier.com/content/search/sciencedirect?start=5975&count=25&query=smart+homes&apiKey=7f59af901d2d86f78a1fd60c1bf9426a&httpAccept=application%2Fjson", "@type": "application/json"}],"entry": [{"@_fa": "true", "load-date":"2021-10-19T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S004579062100481X"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S004579062100481X?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.compeleceng.2021.107536","prism:url":"https://api.elsevier.com/content/article/pii/S004579062100481X","dc:title":"Three-layer hybrid intrusion detection model for smart home malicious attacks","dc:creator":"Lingyun Shi","prism:publicationName":"Computers & Electrical Engineering","prism:volume":"96","prism:coverDate":"2021-12-31","prism:startingPage":"107536","prism:doi":"10.1016/j.compeleceng.2021.107536","openaccess":false,"pii":"S004579062100481X","authors":{"author": [{"$" :"Lingyun Shi"},{"$" :"Longfei Wu"},{"$" :"Zhitao Guan"}]}},{"@_fa": "true", "load-date":"2021-11-11T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0160791X21002839"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0160791X21002839?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.techsoc.2021.101808","prism:url":"https://api.elsevier.com/content/article/pii/S0160791X21002839","dc:title":"Smart but unfriendly: Connected home products as enablers of conflict","dc:creator":"D. D. Furszyfer Del Rio","prism:publicationName":"Technology in Society","prism:volume":"68","prism:coverDate":"2022-02-28","prism:startingPage":"101808","prism:doi":"10.1016/j.techsoc.2021.101808","openaccess":false,"pii":"S0160791X21002839","authors":{"author":"D. D. Furszyfer Del Rio"}},{"@_fa": "true", "load-date":"2021-09-08T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S266729522100026X"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S266729522100026X?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.hcc.2021.100036","prism:url":"https://api.elsevier.com/content/article/pii/S266729522100026X","dc:title":"Access Control and Surveillance in a Smart Home","dc:creator":"Cristina Stolojescu-Crisan","prism:publicationName":"High-Confidence Computing","prism:coverDate":"2021-09-08","prism:startingPage":"100036","prism:doi":"10.1016/j.hcc.2021.100036","openaccess":true,"pii":"S266729522100026X","authors":{"author": [{"$" :"Cristina Stolojescu-Crisan"},{"$" :"Calin Crisan"},{"$" :"Bogdan-Petru Butunoi"}]}},{"@_fa": "true", "load-date":"2021-07-22T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2214629621003042"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2214629621003042?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.erss.2021.102211","prism:url":"https://api.elsevier.com/content/article/pii/S2214629621003042","dc:title":"Motivations, barriers and risks of smart home adoption: From systematic literature review to conceptual framework","dc:creator":"Wenda Li","prism:publicationName":"Energy Research & Social Science","prism:volume":"80","prism:coverDate":"2021-10-31","prism:startingPage":"102211","prism:doi":"10.1016/j.erss.2021.102211","openaccess":false,"pii":"S2214629621003042","authors":{"author": [{"$" :"Wenda Li"},{"$" :"Tan Yigitcanlar"},{"$" :"Aaron Liu"}]}},{"@_fa": "true", "load-date":"2021-07-30T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S016740482100242X"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S016740482100242X?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.cose.2021.102418","prism:url":"https://api.elsevier.com/content/article/pii/S016740482100242X","dc:title":"Cyber-enabled burglary of smart homes","dc:creator":"Duncan Hodges","prism:publicationName":"Computers & Security","prism:volume":"110","prism:coverDate":"2021-11-30","prism:startingPage":"102418","prism:doi":"10.1016/j.cose.2021.102418","openaccess":false,"pii":"S016740482100242X","authors":{"author":"Duncan Hodges"}},{"@_fa": "true", "load-date":"2021-07-28T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0736585321001283"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0736585321001283?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.tele.2021.101689","prism:url":"https://api.elsevier.com/content/article/pii/S0736585321001283","dc:title":"Users’ Preferences for Smart Home Automation – Investigating Aspects of Privacy and Trust","dc:creator":"Eva-Maria Schomakers","prism:publicationName":"Telematics and Informatics","prism:volume":"64","prism:coverDate":"2021-11-30","prism:startingPage":"101689","prism:doi":"10.1016/j.tele.2021.101689","openaccess":false,"pii":"S0736585321001283","authors":{"author": [{"$" :"Eva-Maria Schomakers"},{"$" :"Hannah Biermann"},{"$" :"Martina Ziefle"}]}},{"@_fa": "true", "load-date":"2021-06-20T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2090447921002641"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2090447921002641?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.asej.2021.05.027","prism:url":"https://api.elsevier.com/content/article/pii/S2090447921002641","dc:title":"Flexible smart home design: Case study to design future smart home prototypes","dc:creator":"Raz Kamaran Radha","prism:publicationName":"Ain Shams Engineering Journal","prism:coverDate":"2021-06-20","prism:doi":"10.1016/j.asej.2021.05.027","openaccess":true,"pii":"S2090447921002641","authors":{"author":"Raz Kamaran Radha"}},{"@_fa": "true", "load-date":"2021-07-20T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0160791X21001585"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0160791X21001585?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.techsoc.2021.101683","prism:url":"https://api.elsevier.com/content/article/pii/S0160791X21001585","dc:title":"Prohibitive factors to the acceptance of Internet of Things (IoT) technology in society: A smart-home context using a resistive modelling approach","dc:creator":"Debajyoti Pal","prism:publicationName":"Technology in Society","prism:volume":"66","prism:coverDate":"2021-08-31","prism:startingPage":"101683","prism:doi":"10.1016/j.techsoc.2021.101683","openaccess":false,"pii":"S0160791X21001585","authors":{"author": [{"$" :"Debajyoti Pal"},{"$" :"Xiangmin Zhang"},{"$" :"Saeed Siyal"}]}},{"@_fa": "true", "load-date":"2021-08-19T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2214785321054663"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2214785321054663?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.matpr.2021.08.038","prism:url":"https://api.elsevier.com/content/article/pii/S2214785321054663","dc:title":"The design and fulfillment of a Smart Home (SH) material powered by the IoT using the Blynk app","dc:creator":"Mustafa A. Omran","prism:publicationName":"Materials Today: Proceedings","prism:coverDate":"2021-08-19","prism:doi":"10.1016/j.matpr.2021.08.038","openaccess":false,"pii":"S2214785321054663","authors":{"author": [{"$" :"Mustafa A. Omran"},{"$" :"Bashar J. Hamza"},{"$" :"Wasan K. Saad"}]}},{"@_fa": "true", "load-date":"2021-06-07T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0959652621020631"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0959652621020631?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.jclepro.2021.127845","prism:url":"https://api.elsevier.com/content/article/pii/S0959652621020631","dc:title":"Environmental saving potentials of a smart home system from a life cycle perspective: How green is the smart home?","dc:creator":"Johanna Pohl","prism:publicationName":"Journal of Cleaner Production","prism:volume":"312","prism:coverDate":"2021-08-20","prism:startingPage":"127845","prism:doi":"10.1016/j.jclepro.2021.127845","openaccess":false,"pii":"S0959652621020631","authors":{"author": [{"$" :"Johanna Pohl"},{"$" :"Vivian Frick"},{"$" :"Matthias Finkbeiner"}]}},{"@_fa": "true", "load-date":"2021-07-29T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0267364921000157"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0267364921000157?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.clsr.2021.105542","prism:url":"https://api.elsevier.com/content/article/pii/S0267364921000157","dc:title":"Defence against the dark artefacts: Smart home cybercrimes and cybersecurity standards","dc:creator":"Stanislaw Piasecki","prism:publicationName":"Computer Law & Security Review","prism:volume":"42","prism:coverDate":"2021-09-30","prism:startingPage":"105542","prism:doi":"10.1016/j.clsr.2021.105542","openaccess":true,"pii":"S0267364921000157","authors":{"author": [{"$" :"Stanislaw Piasecki"},{"$" :"Lachlan Urquhart"},{"$" :"Professor Derek McAuley"}]}},{"@_fa": "true", "load-date":"2021-09-08T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0040162521005801"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0040162521005801?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.techfore.2021.121147","prism:url":"https://api.elsevier.com/content/article/pii/S0040162521005801","dc:title":"Ecological determinants of smart home ecosystems: A coopetition framework","dc:creator":"Elisabeth Struckell","prism:publicationName":"Technological Forecasting and Social Change","prism:volume":"173","prism:coverDate":"2021-12-31","prism:startingPage":"121147","prism:doi":"10.1016/j.techfore.2021.121147","openaccess":true,"pii":"S0040162521005801","authors":{"author": [{"$" :"Elisabeth Struckell"},{"$" :"Divesh Ojha"},{"$" :"Amandeep Dhir"}]}},{"@_fa": "true", "load-date":"2021-06-04T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S1386505621001398"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S1386505621001398?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.ijmedinf.2021.104513","prism:url":"https://api.elsevier.com/content/article/pii/S1386505621001398","dc:title":"The effectiveness of smart home technologies to support the health outcomes of community-dwelling older adults living with dementia: A scoping review","dc:creator":"Wendy Moyle","prism:publicationName":"International Journal of Medical Informatics","prism:volume":"153","prism:coverDate":"2021-09-30","prism:startingPage":"104513","prism:doi":"10.1016/j.ijmedinf.2021.104513","openaccess":false,"pii":"S1386505621001398","authors":{"author": [{"$" :"Wendy Moyle"},{"$" :"Jenny Murfield"},{"$" :"Katarzyna Lion"}]}},{"@_fa": "true", "load-date":"2021-04-23T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S266627872100012X"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S266627872100012X?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.egycc.2021.100035","prism:url":"https://api.elsevier.com/content/article/pii/S266627872100012X","dc:title":"Culture, energy and climate sustainability, and smart home technologies: A mixed methods comparison of four countries","dc:creator":"Dylan D. Furszyfer Del Rio","prism:publicationName":"Energy and Climate Change","prism:volume":"2","prism:coverDate":"2021-12-31","prism:startingPage":"100035","prism:doi":"10.1016/j.egycc.2021.100035","openaccess":true,"pii":"S266627872100012X","authors":{"author": [{"$" :"Dylan D. Furszyfer Del Rio"},{"$" :"Benjamin K. Sovacool"},{"$" :"Steve Griffiths"}]}},{"@_fa": "true", "load-date":"2021-03-30T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0959652621011276"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0959652621011276?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.jclepro.2021.126908","prism:url":"https://api.elsevier.com/content/article/pii/S0959652621011276","dc:title":"Smart home and internet of things: A bibliometric study","dc:creator":"Wonyoung Choi","prism:publicationName":"Journal of Cleaner Production","prism:volume":"301","prism:coverDate":"2021-06-10","prism:startingPage":"126908","prism:doi":"10.1016/j.jclepro.2021.126908","openaccess":false,"pii":"S0959652621011276","authors":{"author": [{"$" :"Wonyoung Choi"},{"$" :"Jisu Kim"},{"$" :"Eunil Park"}]}},{"@_fa": "true", "load-date":"2021-05-14T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0142061521003987"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0142061521003987?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.ijepes.2021.107159","prism:url":"https://api.elsevier.com/content/article/pii/S0142061521003987","dc:title":"An optimal scheduling scheme for smart home electricity considering demand response and privacy protection","dc:creator":"Shaomin Zhang","prism:publicationName":"International Journal of Electrical Power & Energy Systems","prism:volume":"132","prism:coverDate":"2021-11-30","prism:startingPage":"107159","prism:doi":"10.1016/j.ijepes.2021.107159","openaccess":false,"pii":"S0142061521003987","authors":{"author": [{"$" :"Shaomin Zhang"},{"$" :"Jieqi Rong"},{"$" :"Baoyi Wang"}]}},{"@_fa": "true", "load-date":"2021-07-26T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2542660521000755"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2542660521000755?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.iot.2021.100431","prism:url":"https://api.elsevier.com/content/article/pii/S2542660521000755","dc:title":"Evaluation of end user requirements for Smart Home applications and services based on a decision support system","dc:creator":"Dede Georgia","prism:publicationName":"Internet of Things","prism:volume":"16","prism:coverDate":"2021-12-31","prism:startingPage":"100431","prism:doi":"10.1016/j.iot.2021.100431","openaccess":false,"pii":"S2542660521000755","authors":{"author": [{"$" :"Dede Georgia"},{"$" :"Filiopoulou Evangelia"},{"$" :"Kamalakis Thomas"}]}},{"@_fa": "true", "load-date":"2021-07-12T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0142061521005974"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0142061521005974?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.ijepes.2021.107358","prism:url":"https://api.elsevier.com/content/article/pii/S0142061521005974","dc:title":"Optimal power management framework for smart homes using electric vehicles and energy storage","dc:creator":"Ubaid ur Rehman","prism:publicationName":"International Journal of Electrical Power & Energy Systems","prism:volume":"134","prism:coverDate":"2022-01-31","prism:startingPage":"107358","prism:doi":"10.1016/j.ijepes.2021.107358","openaccess":false,"pii":"S0142061521005974","authors":{"author": [{"$" :"Ubaid ur Rehman"},{"$" :"Kamran Yaqoob"},{"$" :"Muhammad Adil Khan"}]}},{"@_fa": "true", "load-date":"2021-04-30T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2210670721002584"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2210670721002584?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.scs.2021.102972","prism:url":"https://api.elsevier.com/content/article/pii/S2210670721002584","dc:title":"Optimal two-level active and reactive energy management of residential appliances in smart homes","dc:creator":"Samaneh Zamanloo","prism:publicationName":"Sustainable Cities and Society","prism:volume":"71","prism:coverDate":"2021-08-31","prism:startingPage":"102972","prism:doi":"10.1016/j.scs.2021.102972","openaccess":false,"pii":"S2210670721002584","authors":{"author": [{"$" :"Samaneh Zamanloo"},{"$" :"Hossein Askarian Abyaneh"},{"$" :"Mohsen Azizi"}]}},{"@_fa": "true", "load-date":"2021-09-22T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2214629621003947"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2214629621003947?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.erss.2021.102302","prism:url":"https://api.elsevier.com/content/article/pii/S2214629621003947","dc:title":"A battle over smart standards: Compatibility, governance, and innovation in home energy management systems and smart meters in the Netherlands","dc:creator":"G. Van de Kaa","prism:publicationName":"Energy Research & Social Science","prism:volume":"82","prism:coverDate":"2021-12-31","prism:startingPage":"102302","prism:doi":"10.1016/j.erss.2021.102302","openaccess":true,"pii":"S2214629621003947","authors":{"author": [{"$" :"G. Van de Kaa"},{"$" :"S. Stoccuto"},{"$" :"C. Valladolid Calderón"}]}},{"@_fa": "true", "load-date":"2021-02-05T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S1364032121000502"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S1364032121000502?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.rser.2021.110755","prism:url":"https://api.elsevier.com/content/article/pii/S1364032121000502","dc:title":"A systematic review of the smart energy conservation system: From smart homes to sustainable smart cities","dc:creator":"Hakpyeong Kim","prism:publicationName":"Renewable and Sustainable Energy Reviews","prism:volume":"140","prism:coverDate":"2021-04-30","prism:startingPage":"110755","prism:doi":"10.1016/j.rser.2021.110755","openaccess":false,"pii":"S1364032121000502","authors":{"author": [{"$" :"Hakpyeong Kim"},{"$" :"Heeju Choi"},{"$" :"Taehoon Hong"}]}},{"@_fa": "true", "load-date":"2021-03-20T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S0301421521000653"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S0301421521000653?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.enpol.2021.112196","prism:url":"https://api.elsevier.com/content/article/pii/S0301421521000653","dc:title":"Knowledge, energy sustainability, and vulnerability in the demographics of smart home technology diffusion","dc:creator":"Benjamin K. Sovacool","prism:publicationName":"Energy Policy","prism:volume":"153","prism:coverDate":"2021-06-30","prism:startingPage":"112196","prism:doi":"10.1016/j.enpol.2021.112196","openaccess":true,"pii":"S0301421521000653","authors":{"author": [{"$" :"Benjamin K. Sovacool"},{"$" :"Mari Martiskainen"},{"$" :"Dylan D. Furszyfer Del Rio"}]}},{"@_fa": "true", "load-date":"2021-05-21T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2214629621001985"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2214629621001985?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.erss.2021.102105","prism:url":"https://api.elsevier.com/content/article/pii/S2214629621001985","dc:title":"Controllable, frightening, or fun? Exploring the gendered dynamics of smart home technology preferences in the United Kingdom","dc:creator":"D. D. Furszyfer Del Rio","prism:publicationName":"Energy Research & Social Science","prism:volume":"77","prism:coverDate":"2021-07-31","prism:startingPage":"102105","prism:doi":"10.1016/j.erss.2021.102105","openaccess":false,"pii":"S2214629621001985","authors":{"author": [{"$" :"D. D. Furszyfer Del Rio"},{"$" :"B. K. Sovacool"},{"$" :"M. Martiskainen"}]}},{"@_fa": "true", "load-date":"2021-04-02T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2214579621000411"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2214579621000411?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.bdr.2021.100224","prism:url":"https://api.elsevier.com/content/article/pii/S2214579621000411","dc:title":"The Use of Smart Home Speakers by the Elderly: Exploratory Analyses and Potential for Big Data","dc:creator":"Sandeep Purao","prism:publicationName":"Big Data Research","prism:volume":"25","prism:coverDate":"2021-07-15","prism:startingPage":"100224","prism:doi":"10.1016/j.bdr.2021.100224","openaccess":false,"pii":"S2214579621000411","authors":{"author": [{"$" :"Sandeep Purao"},{"$" :"Haijing Hao"},{"$" :"Chenhang Meng"}]}},{"@_fa": "true", "load-date":"2021-02-20T00:00:00.000Z","link": [{"@_fa": "true", "@ref": "self", "@href": "https://api.elsevier.com/content/article/pii/S2352186421000912"},{"@_fa": "true", "@ref": "scidir", "@href": "https://www.sciencedirect.com/science/article/pii/S2352186421000912?dgcid=api_sd_search-api-endpoint"}],"dc:identifier":"DOI:10.1016/j.eti.2021.101443","prism:url":"https://api.elsevier.com/content/article/pii/S2352186421000912","dc:title":"Smart Home Energy Management Systems in Internet of Things networks for green cities demands and services","dc:creator":"Muhammad Saidu Aliero","prism:publicationName":"Environmental Technology & Innovation","prism:volume":"22","prism:coverDate":"2021-05-31","prism:startingPage":"101443","prism:doi":"10.1016/j.eti.2021.101443","openaccess":false,"pii":"S2352186421000912","authors":{"author": [{"$" :"Muhammad Saidu Aliero"},{"$" :"Kashif Naseer Qureshi"},{"$" :"Gwanggil Jeon"}]}}]}}
"""

# %%
j = json.loads(s)

# %%
j.keys()
# Out:
# dict_keys(['search-results'])

# %%
j['search-results']['link']
# Out:
# [{'@_fa': 'true',
#   '@ref': 'self',
#   '@href': 'https://api.elsevier.com/content/search/sciencedirect?start=0&count=25&query=smart+homes&apiKey=7f59af901d2d86f78a1fd60c1bf9426a&httpAccept=application%2Fjson',
#   '@type': 'application/json'},
#  {'@_fa': 'true',
#   '@ref': 'first',
#   '@href': 'https://api.elsevier.com/content/search/sciencedirect?start=0&count=25&query=smart+homes&apiKey=7f59af901d2d86f78a1fd60c1bf9426a&httpAccept=application%2Fjson',
#   '@type': 'application/json'},
#  {'@_fa': 'true',
#   '@ref': 'next',
#   '@href': 'https://api.elsevier.com/content/search/sciencedirect?start=25&count=25&query=smart+homes&apiKey=7f59af901d2d86f78a1fd60c1bf9426a&httpAccept=application%2Fjson',
#   '@type': 'application/json'},
#  {'@_fa': 'true',
#   '@ref': 'last',
#   '@href': 'https://api.elsevier.com/content/search/sciencedirect?start=5975&count=25&query=smart+homes&apiKey=7f59af901d2d86f78a1fd60c1bf9426a&httpAccept=application%2Fjson',
# ...

# %%
pd.DataFrame.from_dict(j.get('search-results').get("entry"))
# Out:
#     @_fa                 load-date  \
# 0   true  2021-10-19T00:00:00.000Z
# 1   true  2021-11-11T00:00:00.000Z
# 2   true  2021-09-08T00:00:00.000Z
# 3   true  2021-07-22T00:00:00.000Z
# 4   true  2021-07-30T00:00:00.000Z
# 5   true  2021-07-28T00:00:00.000Z
# 6   true  2021-06-20T00:00:00.000Z
# 7   true  2021-07-20T00:00:00.000Z
# 8   true  2021-08-19T00:00:00.000Z
# 9   true  2021-06-07T00:00:00.000Z
# 10  true  2021-07-29T00:00:00.000Z
# 11  true  2021-09-08T00:00:00.000Z
# 12  true  2021-06-04T00:00:00.000Z
# 13  true  2021-04-23T00:00:00.000Z
# 14  true  2021-03-30T00:00:00.000Z
# 15  true  2021-05-14T00:00:00.000Z
# 16  true  2021-07-26T00:00:00.000Z
# 17  true  2021-07-12T00:00:00.000Z
# 18  true  2021-04-30T00:00:00.000Z
# 19  true  2021-09-22T00:00:00.000Z
# 20  true  2021-02-05T00:00:00.000Z
# 21  true  2021-03-20T00:00:00.000Z
# 22  true  2021-05-21T00:00:00.000Z
# 23  true  2021-04-02T00:00:00.000Z
# 24  true  2021-02-20T00:00:00.000Z
#
# ...

# %%
j.get('search-results').get("entry")
# Out:
# [{'@_fa': 'true',
#   'load-date': '2021-10-19T00:00:00.000Z',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/article/pii/S004579062100481X'},
#    {'@_fa': 'true',
#     '@ref': 'scidir',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S004579062100481X?dgcid=api_sd_search-api-endpoint'}],
#   'dc:identifier': 'DOI:10.1016/j.compeleceng.2021.107536',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S004579062100481X',
#   'dc:title': 'Three-layer hybrid intrusion detection model for smart home malicious attacks',
#   'dc:creator': 'Lingyun Shi',
#   'prism:publicationName': 'Computers & Electrical Engineering',
#   'prism:volume': '96',
#   'prism:coverDate': '2021-12-31',
#   'prism:startingPage': '107536',
#   'prism:doi': '10.1016/j.compeleceng.2021.107536',
#   'openaccess': False,
#   'pii': 'S004579062100481X',
#   'authors': {'author': [{'$': 'Lingyun Shi'},
#     {'$': 'Longfei Wu'},
# ...

# %%
{year: index + 1 for index, year in enumerate(range(2016, 2021 + 1))}
# Out:
# {2016: 1, 2017: 2, 2018: 3, 2019: 4, 2020: 5, 2021: 6}

# %%
import pandas as pd

# %%
f = "odds_ratio_module/data/2016/df_LogDEPA Region 0 Odds Ratio CHILD.csv"

# %%
df = pd.read_csv(f)

# %%
for column in df.columns:
    print(column, df[column].unique())
# Out:
# index [ 1839  1840  1841 ... 59788 59789 59790]
# ZEV_MANDATES [1 0]
# GENDER [2. 1. 9.]
# RACE [ 2.  1.  7.  4.  6. 99.  3.  5. 77.]
# POVERTY [0. 1.]
# DENSITY [0.20310216 0.60959825 0.31385899 0.1427092  0.17341616 0.18638748
#  0.14858277 0.02355954 0.08753413 0.0300451  0.1409158  0.04696723
#  0.06778186 0.         0.01468598 0.01615141 1.         0.23156549
#  0.04161477 0.02960076 0.84393819 0.02490431 0.05048694 0.08298685]
# ASTHMA [0 1]
# STATE [ 6.  9. 12. 13. 15. 17. 18. 20. 21. 23. 26. 28. 29. 30. 31. 32. 34. 39.
#  40. 41. 44. 49. 50. 55.]
# EPA_REGION [ 9  1  4  5  7  8  2  6 10]
# YEAR [1]

# %%
for column in df.columns:
    print(column, df[column].unique())
# Out:
# index [ 1839  1840  1841 ... 59788 59789 59790]
# ZEV_MANDATES [1 0]
# GENDER [2. 1. 9.]
# RACE [ 2.  1.  7.  4.  6. 99.  3.  5. 77.]
# POVERTY [0. 1.]
# DENSITY [0.02230831 0.06590606 0.03418727 0.01583101 0.01912441 0.02051562
#  0.01646097 0.00305191 0.00991335 0.0037475  0.01563867 0.00556244
#  0.00779486 0.00052508 0.00210019 0.00225737 0.10777765 0.02536108
#  0.00498838 0.00369984 0.09103962 0.00319614 0.00593994 0.00942564]
# ASTHMA [0 1]
# STATE [ 6.  9. 12. 13. 15. 17. 18. 20. 21. 23. 26. 28. 29. 30. 31. 32. 34. 39.
#  40. 41. 44. 49. 50. 55.]
# EPA_REGION [ 9  1  4  5  7  8  2  6 10]
# YEAR [1]

# %%
df.groupby('GENDER')['index'].nunique()
# Out:
# GENDER
# 1.0    22104
# 2.0    21003
# 9.0      474
# Name: index, dtype: int64

# %%
df['density_lol'] = (df['DENSITY'] - df['DENSITY'].min())/ (df['DENSITY'].max() - df['DENSITY'].min())

# %%
df['density_lol'].unique()
# Out:
# array([0.20310216, 0.60959825, 0.31385899, 0.1427092 , 0.17341616,
#        0.18638748, 0.14858277, 0.02355954, 0.08753413, 0.0300451 ,
#        0.1409158 , 0.04696723, 0.06778186, 0.        , 0.01468598,
#        0.01615141, 1.        , 0.23156549, 0.04161477, 0.02960076,
#        0.84393819, 0.02490431, 0.05048694, 0.08298685])

# %%
import csv
fopen = open(f, "r")
reader = csv.reader(fopen)
for row, _ in zip(reader, range(10)):
    print(row)
# Out:
# ['index', 'ZEV_MANDATES', 'GENDER', 'RACE', 'POVERTY', 'DENSITY', 'ASTHMA', 'STATE', 'EPA_REGION', 'YEAR']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']
# ['47', '1', '2', '2.0', '0.0', '0.0', '0', '6', '9', '-32']

# %%
df.shape
# Out:
# (29764732, 10)

# %%
df
