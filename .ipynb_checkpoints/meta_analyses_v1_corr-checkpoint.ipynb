# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ev_df = pd.read_csv("data/ev_sales/ev_data_preprocessed.csv")
asthma_df = pd.read_csv("odds_ratio_module/combined_OR_aOR.csv")

# %%
df = ev_df.merge(asthma_df, how='left', on=['state_code', 'year'])

# %%
df
# Out:
#              State  FCEV Sales  FCEV Market Share  BEV Sales  \
# 0          Alabama           0                NaN         18
# 1           Alaska           0                NaN          2
# 2          Arizona           0                NaN        355
# 3         Arkansas           0                NaN          2
# 4       California          19                NaN       5062
# ..             ...         ...                ...        ...
# 454       Virginia           0                0.0       5677
# 455     Washington           0                0.0      10256
# 456  West Virginia           0                0.0        179
# 457      Wisconsin           0                0.0       1381
# 458        Wyoming           0                0.0        100
#
#      BEV Market Share  PHEV Sales  PHEV Market Share  year     State Name  \
# 0                 NaN          55                NaN  2011        Alabama
# 1                 NaN           4                NaN  2011         Alaska
# 2                 NaN         102                NaN  2011        Arizona
# 3                 NaN          20                NaN  2011       Arkansas
# 4                 NaN        1656                NaN  2011     California
# ..                ...         ...                ...   ...            ...
# 454            0.0153        1337             0.0036  2019       Virginia
# 455            0.0359        1916             0.0067  2019     Washington
# 456            0.0035          71             0.0014  2019  West Virginia
# 457            0.0057         581             0.0024  2019      Wisconsin
# 458            0.0028          44             0.0012  2019        Wyoming
#
#      state_code  ...  ZEV Mandates  population  at_risk  total_incidence  \
# 0             1  ...             0     1123827  1025208             8530
# 1             2  ...             0      188580   172032             1432
# 2             4  ...             0     1615952  1480061            12315
# 3             5  ...             0      711633   649186             5402
# 4             6  ...             1     9244611  8433370            70167
# ..          ...  ...           ...         ...      ...              ...
# 454          51  ...             0     1860848  1724639            10676
# 455          53  ...             0     1663061  1541330             9541
# 456          54  ...             0      359567   333248             2063
# 457          55  ...             0     1266597  1214574             7519
# 458          56  ...             0      133734   123946              768
#
#      incidence_trap        PR       IR        AF            OR       aOR
# 0               865  0.087753  0.00832  0.101333  4.151245e-01       NaN
# 1                 0  0.087753  0.00832  0.000000  8.574561e-09       NaN
# 2              4980  0.084094  0.00832  0.404398  1.659567e+00  1.280341
# 3               746  0.087753  0.00832  0.138113  5.682501e-01       NaN
# 4             29324  0.087753  0.00832  0.417916  1.714878e+00       NaN
# ..              ...       ...      ...       ...           ...       ...
# 454            1406  0.073197  0.00619  0.131665  8.312632e-01       NaN
# 455            1532  0.073197  0.00619  0.160530  1.014282e+00       NaN
# 456               0  0.073197  0.00619  0.000000  7.694841e-09       NaN
# 457             462  0.041074  0.00619  0.061443  3.889718e-01  0.188445
# 458              62  0.073197  0.00619  0.080411  5.076001e-01       NaN
#
# [459 rows x 25 columns]

# %%
df['pre_trap'] = df['population']*df['PR']*df['AF']

# %%
df['ev_market_share'] = df['ev_sales']/df['total']
df['nonev_market_share'] = df['nonev_sales']/df['total']

# %%
df = df[df['OR'] != 9999]

# %%
def calco(df):
    return df[['ev_sales', 'nonev_sales', 'OR', 'AF', 'incidence_trap', 'pre_trap', 'ev_market_share', 'nonev_market_share']].corr()

# %%
calco(df)
# Out:
#                     ev_sales  nonev_sales        OR        AF  incidence_trap  \
# ev_sales            1.000000     0.608648  0.288861  0.242603        0.656029
# nonev_sales         0.608648     1.000000  0.235216  0.258892        0.805701
# OR                  0.288861     0.235216  1.000000  0.883378        0.461140
# AF                  0.242603     0.258892  0.883378  1.000000        0.463845
# incidence_trap      0.656029     0.805701  0.461140  0.463845        1.000000
# pre_trap            0.624538     0.822066  0.403938  0.477894        0.948353
# ev_market_share     0.708066     0.300471  0.364903  0.301153        0.440088
# nonev_market_share -0.708066    -0.300471 -0.364903 -0.301153       -0.440088
#
#                     pre_trap  ev_market_share  nonev_market_share
# ev_sales            0.624538         0.708066           -0.708066
# nonev_sales         0.822066         0.300471           -0.300471
# OR                  0.403938         0.364903           -0.364903
# AF                  0.477894         0.301153           -0.301153
# incidence_trap      0.948353         0.440088           -0.440088
# pre_trap            1.000000         0.421635           -0.421635
# ev_market_share     0.421635         1.000000           -1.000000
# nonev_market_share -0.421635        -1.000000            1.000000

# %%
tdf = df[df['ZEV Mandates'] == 1]
calco(tdf)
# Out:
#                     ev_sales  nonev_sales        OR        AF  incidence_trap  \
# ev_sales            1.000000     0.806656  0.453869  0.436639        0.675835
# nonev_sales         0.806656     1.000000  0.434064  0.584184        0.916592
# OR                  0.453869     0.434064  1.000000  0.736292        0.580899
# AF                  0.436639     0.584184  0.736292  1.000000        0.664115
# incidence_trap      0.675835     0.916592  0.580899  0.664115        1.000000
# pre_trap            0.652886     0.914189  0.511189  0.702963        0.947551
# ev_market_share     0.867855     0.591081  0.290839  0.245704        0.601221
# nonev_market_share -0.867855    -0.591081 -0.290839 -0.245704       -0.601221
#
#                     pre_trap  ev_market_share  nonev_market_share
# ev_sales            0.652886         0.867855           -0.867855
# nonev_sales         0.914189         0.591081           -0.591081
# OR                  0.511189         0.290839           -0.290839
# AF                  0.702963         0.245704           -0.245704
# incidence_trap      0.947551         0.601221           -0.601221
# pre_trap            1.000000         0.571100           -0.571100
# ev_market_share     0.571100         1.000000           -1.000000
# nonev_market_share -0.571100        -1.000000            1.000000

# %%
tdf = df[df['ZEV Mandates'] == 0]
calco(tdf)
# Out:
#                     ev_sales  nonev_sales        OR        AF  incidence_trap  \
# ev_sales            1.000000     0.587259  0.137851  0.057199        0.380336
# nonev_sales         0.587259     1.000000  0.087098  0.092330        0.781693
# OR                  0.137851     0.087098  1.000000  0.914503        0.435599
# AF                  0.057199     0.092330  0.914503  1.000000        0.436991
# incidence_trap      0.380336     0.781693  0.435599  0.436991        1.000000
# pre_trap            0.374752     0.805971  0.332714  0.410901        0.936534
# ev_market_share     0.575233    -0.031866  0.318341  0.251484       -0.015802
# nonev_market_share -0.575233     0.031866 -0.318341 -0.251484        0.015802
#
#                     pre_trap  ev_market_share  nonev_market_share
# ev_sales            0.374752         0.575233           -0.575233
# nonev_sales         0.805971        -0.031866            0.031866
# OR                  0.332714         0.318341           -0.318341
# AF                  0.410901         0.251484           -0.251484
# incidence_trap      0.936534        -0.015802            0.015802
# pre_trap            1.000000         0.009035           -0.009035
# ev_market_share     0.009035         1.000000           -1.000000
# nonev_market_share -0.009035        -1.000000            1.000000

# %%
df[df['state_code'] == 6]
# Out:
#           State  FCEV Sales  FCEV Market Share  BEV Sales  BEV Market Share  \
# 4    California          19                NaN       5062               NaN
# 55   California          30                NaN       5160               NaN
# 106  California          19             0.0000      20943            0.0129
# 157  California          49             0.0000      28749            0.0164
# 208  California          74             0.0000      33945            0.0174
# 259  California        1025             0.0005      38861            0.0197
# 310  California        1859             0.0010      49765            0.0258
# 361  California        1729             0.0009      91171            0.0466
# 412  California        1764             0.0009     100549            0.0516
#
#      PHEV Sales  PHEV Market Share  year  State Name  state_code  ...  \
# 4          1656                NaN  2011  California           6  ...
# 55        13971                NaN  2012  California           6  ...
# 106       17512             0.0108  2013  California           6  ...
# 157       29797             0.0170  2014  California           6  ...
# 208       27645             0.0142  2015  California           6  ...
# 259       34993             0.0177  2016  California           6  ...
# 310       45107             0.0234  2017  California           6  ...
# 361       62271             0.0318  2018  California           6  ...
# 412       44471             0.0228  2019  California           6  ...
#
#      at_risk  total_incidence  incidence_trap        PR        IR        AF  \
# 4    8433370            70167           29324  0.087753  0.008320  0.417916
# 55   8389579           109451           43334  0.087448  0.013046  0.395918
# 106  8346688            42984           17676  0.088534  0.005150  0.411209
# 157  8328852            78901           31114  0.088164  0.009473  0.394338
# 208  8466236            76204           29419  0.071341  0.009001  0.386047
# 259  8389631            87843           32662  0.076760  0.010470  0.371822
# 310  8486195            85900           32860  0.061917  0.010122  0.382536
# 361  8419595            68333           25219  0.061544  0.008116  0.369059
# 412  8243954            51031           18026  0.073155  0.006190  0.353229
#
#            OR       aOR       pre_trap  nonev_market_share
# 4    1.714878       NaN  339031.157559                 NaN
# 55   2.372681  1.947620  318300.715443                 NaN
# 106  1.193013  0.770232  333385.191509            0.976302
# 157  1.723461  1.306882  317561.757817            0.966574
# 208  1.736792  1.160817  251080.888086            0.968391
# 259  2.322102  1.649317  259357.120443            0.962125
# 310  2.386239  1.244844  214266.302999            0.949851
# 361  2.290480  1.254224  203778.605817            0.920759
# 412  2.232486  1.460315  229841.681640            0.924745
#
# [9 rows x 27 columns]

# %%
# OR
df.boxplot(column=['OR', 'aOR'], by=['ZEV Mandates'], layout = (2,1))
df[df['ZEV Mandates'] == 1].boxplot(column=['OR', 'aOR'], by=['year'], layout = (2,1))
df[df['ZEV Mandates'] == 0].boxplot(column=['OR', 'aOR'], by=['year'], layout = (2,1))

# %%
df.boxplot(column=['AF'], by=['ZEV Mandates'], layout = (2,1))
df[df['ZEV Mandates'] == 1].boxplot(column=['AF'], by=['year'], layout = (2,1))
df[df['ZEV Mandates'] == 0].boxplot(column=['AF'], by=['year'], layout = (2,1))
# Out:
# array([<AxesSubplot:title={'center':'AF'}, xlabel='[year]'>,
#        <AxesSubplot:>], dtype=object)

# %%
df.boxplot(column=['incidence_trap'], by=['ZEV Mandates'], layout = (2,1))
df[df['ZEV Mandates'] == 1].boxplot(column=['incidence_trap'], by=['year'], layout = (2,1))
df[df['ZEV Mandates'] == 0].boxplot(column=['incidence_trap'], by=['year'], layout = (2,1))
# Out:
# array([<AxesSubplot:title={'center':'incidence_trap'}, xlabel='[year]'>,
#        <AxesSubplot:>], dtype=object)

# %%
df[df['year'] == 2011].sort_values(by = 'incidence_trap', ascending=False)[['State', 'incidence_trap']]
# Out:
#                    State  incidence_trap
# 4             California           29324
# 43                 Texas           12159
# 32              New York           10210
# 13              Illinois            7021
# 38          Pennsylvania            6864
# 2                Arizona            4980
# 22              Michigan            4894
# 9                Florida            4622
# 30            New Jersey            4594
# 44                  Utah            4175
# 35                  Ohio            3827
# 21         Massachusetts            2991
# 10               Georgia            2701
# 5               Colorado            2637
# 46              Virginia            2424
# 14               Indiana            2299
# 33        North Carolina            2262
# 20              Maryland            2194
# 6            Connecticut            1841
# 28                Nevada            1829
# 25              Missouri            1798
# 42             Tennessee            1781
# 49             Wisconsin            1745
# 23             Minnesota            1561
# 18             Louisiana            1443
# 31            New Mexico            1370
# 36              Oklahoma            1305
# 16                Kansas            1140
# 17              Kentucky            1034
# 40        South Carolina            1018
# 37                Oregon             968
# 0                Alabama             865
# 15                  Iowa             783
# 3               Arkansas             746
# 12                 Idaho             596
# 24           Mississippi             554
# 27              Nebraska             503
# 47            Washington             489
# 39          Rhode Island             447
# 7               Delaware             441
# 8   District Of Columbia             344
# 48         West Virginia             314
# 11                Hawaii             310
# 29         New Hampshire             237
# 19                 Maine             236
# 41          South Dakota             209
# 26               Montana             193
# 45               Vermont             168
# 34          North Dakota             154
# 50               Wyoming             142
# 1                 Alaska               0

# %%
df[df['year'] == 2019].sort_values(by = 'incidence_trap', ascending=False)[['State', 'incidence_trap']]
# Out:
#                     State  incidence_trap
# 412            California           18026
# 451                 Texas            7190
# 417               Florida            3959
# 410               Arizona            3078
# 421              Illinois            2851
# 440              New York            2760
# 438            New Jersey            2512
# 446          Pennsylvania            1975
# 429         Massachusetts            1805
# 436                Nevada            1704
# 455            Washington            1532
# 454              Virginia            1406
# 443                  Ohio            1398
# 452                  Utah            1141
# 428              Maryland            1099
# 430              Michigan            1055
# 414           Connecticut            1030
# 413              Colorado             978
# 441        North Carolina             939
# 418               Georgia             891
# 433              Missouri             825
# 422               Indiana             815
# 450             Tennessee             738
# 431             Minnesota             623
# 444              Oklahoma             611
# 426             Louisiana             540
# 425              Kentucky             530
# 445                Oregon             464
# 457             Wisconsin             462
# 439            New Mexico             443
# 448        South Carolina             320
# 408               Alabama             308
# 447          Rhode Island             294
# 416  District Of Columbia             268
# 424                Kansas             262
# 415              Delaware             228
# 420                 Idaho             205
# 419                Hawaii             185
# 411              Arkansas             156
# 423                  Iowa             150
# 432           Mississippi             107
# 427                 Maine             101
# 449          South Dakota              89
# 442          North Dakota              77
# 409                Alaska              63
# 458               Wyoming              62
# 453               Vermont              46
# 437         New Hampshire              40
# 434               Montana              12
# 456         West Virginia               0

# %%
df[df['ZEV Mandates'] == 1]['State'].unique()
# Out:
# array(['California', 'Connecticut', 'Maine', 'Maryland', 'Massachusetts',
#        'New Jersey', 'New York', 'Oregon', 'Rhode Island', 'Vermont'],
#       dtype=object)

# %%
df[df['State'] == 'Massachusetts']
# Out:
#              State  FCEV Sales  FCEV Market Share  BEV Sales  \
# 21   Massachusetts           0                NaN          7
# 72   Massachusetts           0                NaN        216
# 123  Massachusetts           0                0.0        592
# 174  Massachusetts           0                0.0        747
# 225  Massachusetts           0                0.0        845
# 276  Massachusetts           0                0.0       1105
# 327  Massachusetts           0                0.0       1885
# 378  Massachusetts           0                0.0       4959
# 429  Massachusetts           0                0.0       5646
#
#      BEV Market Share  PHEV Sales  PHEV Market Share  year     State Name  \
# 21                NaN         107                NaN  2011  Massachusetts
# 72                NaN         973                NaN  2012  Massachusetts
# 123            0.0019        1233             0.0039  2013  Massachusetts
# 174            0.0022         756             0.0022  2014  Massachusetts
# 225            0.0024         821             0.0023  2015  Massachusetts
# 276            0.0032        1800             0.0052  2016  Massachusetts
# 327            0.0055        2747             0.0080  2017  Massachusetts
# 378            0.0139        4031             0.0113  2018  Massachusetts
# 429            0.0162        2212             0.0063  2019  Massachusetts
#
#      state_code  ...  at_risk  total_incidence  incidence_trap        PR  \
# 21           25  ...  1286301            10703            2991  0.087753
# 72           25  ...  1278307            11542            2680  0.089157
# 123          25  ...  1270032            10189            2378  0.091582
# 174          25  ...  1266115            11995            2759  0.090936
# 225          25  ...  1269161            11424            2724  0.084102
# 276          25  ...  1267920            13276            2010  0.080084
# 327          25  ...  1267356            12829            1844  0.077128
# 378          25  ...  1264515            10263            2288  0.073470
# 429          25  ...  1253779             7761            1805  0.073197
#
#            IR        AF        OR  aOR      pre_trap  nonev_market_share
# 21   0.008320  0.279385  1.146760  NaN  34569.647477                 NaN
# 72   0.009028  0.232179  0.962773  NaN  29051.580059                 NaN
# 123  0.008022  0.233397  1.054474  NaN  29883.674620            0.994227
# 174  0.009473  0.229953  1.005057  NaN  29124.159105            0.995626
# 225  0.009001  0.238406  1.073517  NaN  27783.868951            0.995333
# 276  0.010470  0.151375  0.944490  NaN  16708.726651            0.991608
# 327  0.010122  0.143730  0.895243  NaN  15223.565386            0.986510
# 378  0.008116  0.222904  1.384252  NaN  22350.752138            0.974801
# 429  0.006190  0.232533  1.468851  NaN  23025.627312            0.977620
#
# [9 rows x 27 columns]
